# %% [markdown]
# # 전처리를 완료한 데이터를 분석하는 과정이다.

# %% [markdown]
# # 파일 불러오기

# %%
import pickle

# %%
with open("./kbo_sal/taza_sal.pkl","rb") as f:
    taza_sal = pickle.load(f)

# %%
with open("./kbo_sal/tusu_sal.pkl","rb") as f:
    tusu_sal = pickle.load(f)

# %%
with open("./kbo_sal/team.pkl","rb") as f:
    team = pickle.load(f)

# %%
taza_sal.head(1)
# Out:
#     이름  팀명     타율  경기수  득점   안타 이루타 삼루타  홈런   타점     Key                  경력  \
# 0  이정후  키움  0.349  142  85  193  36  10  23  113  키움_이정후  광주서석초-휘문중-휘문고-히어로즈
#
#    연봉(원화)_2022  연봉(원화)_2023      연봉차
# 0      75000.0     110000.0  35000.0

# %%
tusu_sal.head(1)
# Out:
#    선수명  팀명 평균자책점  경기   승  패 세이브 홀드     승률   이닝  ... 사구   삼진  실점 자책점 이닝당_출루허용률  \
# 0  안우진  키움  2.11  30  15  8   0  0  0.652  196  ...  4  224  51  46      0.95
#
#       Key 연봉(원화)_2022          경력 연봉(원화)_2023      연봉차
# 0  키움_안우진     15000.0   강남초-서울이수중     35000.0  20000.0
#
# [1 rows x 23 columns]

# %%
team
# Out:
#     팀명  경기수   승   패  무     승률  연속        홈       원정
# 0  SSG  144  88  52  4  0.629  4패  49-0-23  39-4-29
# 1   키움  144  80  62  2  0.563  1승  39-1-32  41-1-30
# 2   LG  144  87  55  2  0.613  1승  38-1-33  49-1-22
# 3   KT  144  80  62  2  0.563  1패  40-1-31  40-1-31
# 4  KIA  144  70  73  1  0.490  1패  31-0-41  39-1-32
# 5   NC  144  67  74  3  0.475  1패  35-3-34  32-0-40
# 6   삼성  144  66  76  2  0.465  2승  33-2-37  33-0-39
# 7   롯데  144  64  76  4  0.457  1승  27-3-42  37-1-34
# 8   두산  144  60  82  2  0.423  2패  29-1-42  31-1-40
# 9   한화  144  46  96  2  0.324  1패  28-0-44  18-2-52

# %%
# 한글 폰트 설정 
from matplotlib import font_manager, rc
font_path = "./font/malgun.ttf"
font_name = font_manager.FontProperties(fname = font_path).get_name()
rc('font', family=font_name)

# %% [markdown]
# # 타자 선수들의 연봉 확인하기

# %%
taza_sal.sort_values('연봉(원화)_2022',ascending = False).head(10).loc[:,['Key','연봉(원화)_2022']]
# Out:
#         Key  연봉(원화)_2022
# 43  SSG_추신수     270000.0
# 39  SSG_한유섬     240000.0
# 4   KIA_나성범     200000.0
# 2    NC_박건우     190000.0
# 26   NC_손아섭     150000.0
# 47   두산_김재환     150000.0
# 20   LG_김현수     150000.0
# 17   두산_허경민     120000.0
# 37   SSG_최정     120000.0
# 23   NC_양의지     100000.0

# %%
# 2022년 기준 타자 연봉 TOP10 graph
taza_sal.sort_values('연봉(원화)_2022',ascending = False).head(10).loc[:,['Key','연봉(원화)_2022']].set_index('Key').plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Key'>

# %%
# 2022년 기준 타자 연봉 BOTTOM10
taza_sal.sort_values('연봉(원화)_2022',ascending = True).head(10).loc[:,['Key','연봉(원화)_2022']]
# Out:
#         Key  연봉(원화)_2022
# 51   한화_김태연       5600.0
# 45  KIA_황대인       6500.0
# 6    LG_문보경       6800.0
# 48   키움_송성문       7500.0
# 29  KIA_류지혁      10500.0
# 40   두산_강승호      11500.0
# 31  KIA_박찬호      12000.0
# 24   한화_노시환      12000.0
# 13  SSG_박성한      14000.0
# 12  SSG_최지훈      15000.0

# %%
# 2022년 기준 타자 연봉 BOTTOM10 graph
taza_sal.sort_values('연봉(원화)_2022',ascending = True).head(10).loc[:,['Key','연봉(원화)_2022']].set_index('Key').plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Key'>

# %% [markdown]
# # 투수 선수들의 연봉 확인하기

# %%
# 2022년 기준 투수 연봉 TOP10
tusu_sal.sort_values('연봉(원화)_2022',ascending = False).head(10).loc[:,['Key','연봉(원화)_2022']]
# Out:
#          Key  연봉(원화)_2022
# 1    SSG_김광현     810000.0
# 7    NC_루친스키     187147.0
# 6     SSG_폰트     128663.0
# 8     삼성_뷰캐넌     128663.0
# 4      LG_켈리     105270.0
# 5     키움_요키시     105270.0
# 15   KIA_양현종     100000.0
# 21  KT_데스파이네      81876.0
# 3    삼성_수아레즈      81876.0
# 2     LG_플럿코      58483.0

# %%
# 2022년 기준 투수 연봉 TOP10 graph
tusu_sal.sort_values('연봉(원화)_2022',ascending = False).head(10).loc[:,['Key','연봉(원화)_2022']].set_index('Key').plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Key'>

# %%
# 2022년 기준 타자 연봉 BOTTOM10 graph
tusu_sal.sort_values('연봉(원화)_2022',ascending = True).head(10).loc[:,['Key','연봉(원화)_2022']].set_index('Key').plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Key'>

# %% [markdown]
# # 2022년 투수 / 타자 연봉 정보

# %%
# 2022년 기준 전체 투수 연봉 통계량
tusu_sal['연봉(원화)_2022'].describe()
# Out:
# count        22.000000
# mean      94753.090909
# std      166996.370010
# min        6500.000000
# 25%       21500.000000
# 50%       50610.000000
# 75%      103952.500000
# max      810000.000000
# Name: 연봉(원화)_2022, dtype: float64

# %%
# 2022년 기준 전체 타자 연봉 통계량
taza_sal['연봉(원화)_2022'].describe()
# Out:
# count        52.000000
# mean      64804.423077
# std       61102.282706
# min        5600.000000
# 25%       22272.500000
# 50%       47500.000000
# 75%       81876.000000
# max      270000.000000
# Name: 연봉(원화)_2022, dtype: float64

# %%
# 연봉을 많이 받은 타자는 타율이 높은지..
a = taza_sal.loc[:,['이름','타율','연봉(원화)_2022']]
a.reset_index(drop = True,inplace=True)
a
# Out:
#        이름     타율  연봉(원화)_2022
# 0     이정후  0.349      75000.0
# 1     피렐라  0.342      70180.0
# 2     박건우  0.336     190000.0
# 3     이대호  0.331      80000.0
# 4     나성범  0.320     200000.0
# 5     김혜성  0.318      32000.0
# 6     문보경  0.315       6800.0
# 7   소크라테스  0.311      58483.0
# 8   페르난데스  0.309      70180.0
# 9     조용호  0.308      24000.0
# 10    한동희  0.307      17200.0
# 11    전준우  0.304      50000.0
# 12    최지훈  0.304      15000.0
# 13    박성한  0.298      14000.0
# 14    마티니  0.296      51465.0
# 15    채은성  0.296      28000.0
# 16    박해민  0.289      60000.0
# 17    허경민  0.289     120000.0
# 18    터크먼  0.289      81876.0
# 19    김선빈  0.287      45000.0
# 20    김현수  0.286     150000.0
# 21    홍창기  0.286      32000.0
# 22    안치홍  0.284     100000.0
# 23    양의지  0.283     100000.0
# 24    노시환  0.281      12000.0
# 25    노진혁  0.280      23000.0
# 26    손아섭  0.277     150000.0
# 27    푸이그  0.277      81876.0
# 28    박병호  0.275      60000.0
# 29    류지혁  0.274      10500.0
# ...

# %%
# 상관분석을 하기 위해 불러옴
import scipy.stats as stats

# %% [markdown]
# # 타자들의 타율과 2022년 연봉의 상관관계

# %%
import numpy as np

# %%
# 결측치 제거
a.dropna(inplace = True)

# %%
a['타율'] = a['타율'].apply(lambda x : float(x))

# %%
a.corr()
# Out:
#                    타율  연봉(원화)_2022
# 타율           1.000000     0.107376
# 연봉(원화)_2022  0.107376     1.000000

# %%
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 52 entries, 0 to 52
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   이름           52 non-null     object
#  1   타율           52 non-null     float64
#  2   연봉(원화)_2022  52 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 1.6+ KB

# %%
a['연봉(원화)_2022'].reset_index(drop=True,inplace=True)

# %%
a['타율'].reset_index(drop = True, inplace= True)

# %%
fig = plt.figure(figsize=(12, 12))
ax = fig.add_subplot(111)
# 산점도
ax.scatter(a['연봉(원화)_2022'],a['타율'])
ax.set_xlabel('연봉(원화)_2022')
ax.set_ylabel('타율')
plt.title("타율과 연봉(2022)의 산점도")

for i, txt in enumerate(a['이름']):
    plt.text(a['연봉(원화)_2022'][i], a['타율'][i], txt)
plt.show()

# %% [markdown]
# # 선수별 2022년 연봉과 타율의 상관분석
# * 귀무가설 : 선수별 2022년 연봉과 타율은 상관관계가 없다.
# * 대립가설 : 선수별 2022년 연봉과 타율은 상관관계가 있다.

# %%
stats.pearsonr(a['연봉(원화)_2022'],a['타율'])
# Out:
# PearsonRResult(statistic=0.1073764477809853, pvalue=0.44864583452211276)

# %% [markdown]
# ### 상관분석의 해석
# * 검정결과 상관계수는 0.1073의 값이 나왔고 p값은 0.4486으로 유의수준 0.05보다 크므로 귀무가설을 기각할 수 없다.
# * 즉, 선수별 2022년 연봉과 타율은 상관관계가 없다라는 결과에 도달하였음

# %%
a.sort_values('연봉(원화)_2022',ascending = False)
# Out:
#        이름     타율  연봉(원화)_2022
# 43    추신수  0.259     270000.0
# 39    한유섬  0.264     240000.0
# 4     나성범  0.320     200000.0
# 2     박건우  0.336     190000.0
# 26    손아섭  0.277     150000.0
# 47    김재환  0.248     150000.0
# 20    김현수  0.286     150000.0
# 17    허경민  0.289     120000.0
# 37     최정  0.266     120000.0
# 23    양의지  0.283     100000.0
# 22    안치홍  0.284     100000.0
# 38    최형우  0.264      90000.0
# 27    푸이그  0.277      81876.0
# 18    터크먼  0.289      81876.0
# 3     이대호  0.331      80000.0
# 0     이정후  0.349      75000.0
# 1     피렐라  0.342      70180.0
# 8   페르난데스  0.309      70180.0
# 16    박해민  0.289      60000.0
# 32    오지환  0.269      60000.0
# 42    정수빈  0.259      60000.0
# 28    박병호  0.275      60000.0
# 33    오재일  0.268      60000.0
# 7   소크라테스  0.311      58483.0
# 14    마티니  0.296      51465.0
# 11    전준우  0.304      50000.0
# 19    김선빈  0.287      45000.0
# 35    박민우  0.267      41000.0
# 41    황재균  0.262      40000.0
# 49    양석환  0.244      39000.0
# ...

# %% [markdown]
# # 타자들의 타율과 2023년 연봉의 상관관계

# %%
b = taza_sal.loc[:,['이름','타율','연봉(원화)_2023']]
b
# Out:
#        이름     타율  연봉(원화)_2023
# 0     이정후  0.349     110000.0
# 1     피렐라  0.342     148908.0
# 2     박건우  0.336      90000.0
# 3     이대호  0.331          NaN
# 4     나성범  0.320      80000.0
# 5     김혜성  0.318      42000.0
# 6     문보경  0.315      17000.0
# 7   소크라테스  0.311      62045.0
# 8   페르난데스  0.309          NaN
# 9     조용호  0.308      32000.0
# 10    한동희  0.307      19260.0
# 11    전준우  0.304      50000.0
# 12    최지훈  0.304      30000.0
# 13    박성한  0.298      27000.0
# 14    마티니  0.296          NaN
# 15    채은성  0.296          NaN
# 16    박해민  0.289      60000.0
# 17    허경민  0.289     120000.0
# 18    터크먼  0.289          NaN
# 19    김선빈  0.287      45000.0
# 20    김현수  0.286     100000.0
# 21    홍창기  0.286      30000.0
# 22    안치홍  0.284      50000.0
# 23    양의지  0.283          NaN
# 24    노시환  0.281      13100.0
# 25    노진혁  0.280          NaN
# 26    손아섭  0.277      50000.0
# 27    푸이그  0.277          NaN
# 28    박병호  0.275      70000.0
# 29    류지혁  0.274      15500.0
# ...

# %%
#FA선수와 외국으로 돌아간 선수들의 2023연봉이 없으므로 제거해주기
b.dropna(inplace = True)

# %%
b['타율'] = b['타율'].apply(lambda x : float(x))

# %%
b.corr()
# Out:
#                    타율  연봉(원화)_2023
# 타율           1.000000     0.170059
# 연봉(원화)_2023  0.170059     1.000000

# %%
b.reset_index(drop=True,inplace = True)

# %% [markdown]
# # 선수별 타율과 2023 연봉의 상관분석
# * 귀무가설 : 선수별 타율과 2023 연봉에는 상관관계가 없다.
# * 대립가설 : 선수별 타율과 2023 연봉에는 상관관계가 있다.

# %%
stats.pearsonr(b['연봉(원화)_2023'],b['타율'])
# Out:
# PearsonRResult(statistic=0.1700588345008627, pvalue=0.28160810961386845)

# %% [markdown]
# ### 상관분석의 해석
# * 검정 결과 상관계수는 0.17005이고, p값은 0.2816으로 유의수준 0.05보다 크므로 귀무가설을 기각할 수 없다.
# * 즉, 선수별 타율과 2023 연봉에는 상관이 없다는 결과에 도달하였다.

# %%
fig = plt.figure(figsize=(12, 12))
ax = fig.add_subplot(111)
# 산점도
ax.scatter(b['연봉(원화)_2023'],b['타율'])
ax.set_xlabel('연봉(원화)_2023')
ax.set_ylabel('타율')
plt.title("타율과 연봉(2023)의 산점도")

for i, txt in enumerate(b['이름']):
    plt.text(b['연봉(원화)_2023'][i], b['타율'][i], txt)
plt.show()

# %%
taza_sal
# Out:
#        이름   팀명     타율  경기수   득점   안타 이루타 삼루타  홈런   타점        Key  \
# 0     이정후   키움  0.349  142   85  193  36  10  23  113     키움_이정후
# 1     피렐라   삼성  0.342  141  102  192  33   4  28  109     삼성_피렐라
# 2     박건우   NC  0.336  111   52  137  18   1  10   61     NC_박건우
# 3     이대호   롯데  0.331  142   53  179  23   0  23  101     롯데_이대호
# 4     나성범  KIA  0.320  144   92  180  39   2  21   97    KIA_나성범
# 5     김혜성   키움  0.318  129   81  164  18   7   4   48     키움_김혜성
# 6     문보경   LG  0.315  126   52  128  22   3   9   56     LG_문보경
# 7   소크라테스  KIA  0.311  127   83  160  29   7  17   77  KIA_소크라테스
# 8   페르난데스   두산  0.309  139   52  157  28   0   6   77   두산_페르난데스
# 9     조용호   KT  0.308  131   52  146  18   4   3   44     KT_조용호
# 10    한동희   롯데  0.307  129   43  140  27   0  14   65     롯데_한동희
# 11    전준우   롯데  0.304  120   73  143  31   1  11   68     롯데_전준우
# 12    최지훈  SSG  0.304  144   93  173  32   4  10   61    SSG_최지훈
# ...

# %%
taza_sal['타율'] = taza_sal['타율'].apply(lambda x : float(x))

# %%
aa = taza_sal.groupby(['팀명'])[['타율']].mean()
aa
# Out:
#            타율
# 팀명
# KIA  0.278250
# KT   0.270200
# LG   0.285143
# NC   0.289833
# SSG  0.278200
# 두산   0.268833
# 롯데   0.306500
# 삼성   0.305000
# 키움   0.291600
# 한화   0.268400

# %% [markdown]
# # 팀별 평균 타율과 승률의 상관관계

# %%
import pandas as pd

# %%
team_taza_tmp = pd.merge(team,aa,left_on = '팀명', right_on = '팀명',how = 'left')

# %%
team_taza_tmp.columns = ['팀명', '경기수', '승', '패', '무', '승률', '연속', '홈', '원정', '평균타율']

# %%
team_taza_tmp
# Out:
#     팀명  경기수   승   패  무     승률  연속        홈       원정      평균타율
# 0  SSG  144  88  52  4  0.629  4패  49-0-23  39-4-29  0.278200
# 1   키움  144  80  62  2  0.563  1승  39-1-32  41-1-30  0.291600
# 2   LG  144  87  55  2  0.613  1승  38-1-33  49-1-22  0.285143
# 3   KT  144  80  62  2  0.563  1패  40-1-31  40-1-31  0.270200
# 4  KIA  144  70  73  1  0.490  1패  31-0-41  39-1-32  0.278250
# 5   NC  144  67  74  3  0.475  1패  35-3-34  32-0-40  0.289833
# 6   삼성  144  66  76  2  0.465  2승  33-2-37  33-0-39  0.305000
# 7   롯데  144  64  76  4  0.457  1승  27-3-42  37-1-34  0.306500
# 8   두산  144  60  82  2  0.423  2패  29-1-42  31-1-40  0.268833
# 9   한화  144  46  96  2  0.324  1패  28-0-44  18-2-52  0.268400

# %% [markdown]
# # 팀 평균 타율과 팀 승률의 상관분석
# * 귀무가설 : 팀 평균 타율과 팀 승률에는 상관관계가 없다.
# * 대립가설 : 팀 평균 타율과 팀 승률에는 상관관계가 있다.

# %%
team_taza_tmp['경기수'] = team_taza_tmp['경기수'].apply(lambda x : int(x))
team_taza_tmp['승'] = team_taza_tmp['승'].apply(lambda x : int(x))
team_taza_tmp['패'] = team_taza_tmp['패'].apply(lambda x : int(x))
team_taza_tmp['무'] = team_taza_tmp['무'].apply(lambda x : int(x))
team_taza_tmp['승률'] = team_taza_tmp['승률'].apply(lambda x : float(x))

# %%
stats.pearsonr(team_taza_tmp['평균타율'],team_taza_tmp['승률'])
# Out:
# PearsonRResult(statistic=0.09464163633867723, pvalue=0.7948158391290246)

# %% [markdown]
# ### 상관분석의 해석
# * 검정 결과 상관계수는 0.09464이고, p값은 0.794815으로 유의수준 0.05보다 크므로 귀무가설을 기각할 수 없다.
# * 즉, 팀별 평균타율과 팀 승률에는 상관이 없다는 결과에 도달하였다.

# %%
fig = plt.figure(figsize=(12, 12))
ax = fig.add_subplot(111)
# 산점도
ax.scatter(team_taza_tmp['평균타율'],team_taza_tmp['승률'])
ax.set_xlabel('평균타율')
ax.set_ylabel('팀 승률')
plt.title("평균타율과 팀 승률의 산점도")
for i, txt in enumerate(team_taza_tmp['팀명']):
    plt.text(team_taza_tmp['평균타율'][i], team_taza_tmp['승률'][i], txt)
plt.show()

# %% [markdown]
# # 각 팀내 최고 타율과 팀 승률과의 상관분석

# %%
taza_sal.head(1)
# Out:
#     이름  팀명     타율  경기수  득점   안타 이루타 삼루타  홈런   타점     Key                  경력  \
# 0  이정후  키움  0.349  142  85  193  36  10  23  113  키움_이정후  광주서석초-휘문중-휘문고-히어로즈
#
#    연봉(원화)_2022  연봉(원화)_2023      연봉차
# 0      75000.0     110000.0  35000.0

# %%
taza_sal['득점'] = taza_sal['득점'].apply(lambda x:int(x))
taza_sal['안타'] = taza_sal['안타'].apply(lambda x:int(x))
taza_sal['이루타'] = taza_sal['이루타'].apply(lambda x:int(x))
taza_sal['삼루타'] = taza_sal['삼루타'].apply(lambda x:int(x))
taza_sal['타점'] = taza_sal['타점'].apply(lambda x:int(x))

# %%
taza_sal.groupby(['팀명'])[['타율']].max().reset_index()
# Out:
#     팀명     타율
# 0  KIA  0.320
# 1   KT  0.308
# 2   LG  0.315
# 3   NC  0.336
# 4  SSG  0.304
# 5   두산  0.309
# 6   롯데  0.331
# 7   삼성  0.342
# 8   키움  0.349
# 9   한화  0.289

# %%
team_max = pd.merge(team,taza_sal.groupby(['팀명'])[['타율']].max().reset_index(),left_on='팀명',right_on='팀명')
team_max
# Out:
#     팀명  경기수   승   패  무     승률  연속        홈       원정     타율
# 0  SSG  144  88  52  4  0.629  4패  49-0-23  39-4-29  0.304
# 1   키움  144  80  62  2  0.563  1승  39-1-32  41-1-30  0.349
# 2   LG  144  87  55  2  0.613  1승  38-1-33  49-1-22  0.315
# 3   KT  144  80  62  2  0.563  1패  40-1-31  40-1-31  0.308
# 4  KIA  144  70  73  1  0.490  1패  31-0-41  39-1-32  0.320
# 5   NC  144  67  74  3  0.475  1패  35-3-34  32-0-40  0.336
# 6   삼성  144  66  76  2  0.465  2승  33-2-37  33-0-39  0.342
# 7   롯데  144  64  76  4  0.457  1승  27-3-42  37-1-34  0.331
# 8   두산  144  60  82  2  0.423  2패  29-1-42  31-1-40  0.309
# 9   한화  144  46  96  2  0.324  1패  28-0-44  18-2-52  0.289

# %%
team_max['경기수'] = team_max['경기수'].apply(lambda x :int(x))
team_max['승'] = team_max['승'].apply(lambda x :int(x))
team_max['패'] = team_max['패'].apply(lambda x :int(x))
team_max['무'] = team_max['무'].apply(lambda x :int(x))
team_max['승률'] = team_max['승률'].apply(lambda x :float(x))

# %%
fig = plt.figure(figsize=(12, 12))
ax = fig.add_subplot(111)
# 산점도
ax.scatter(team_max['타율'],team_max['승률'])
ax.set_xlabel('팀 최고타율')
ax.set_ylabel('팀 승률')
plt.title("팀 최고타율과 팀 승률의 산점도")
for i, txt in enumerate(team_max['팀명']):
    plt.text(team_max['타율'][i], team_max['승률'][i], txt)
plt.show()

# %% [markdown]
# # 팀 평균 타율과 팀 승률의 상관분석
# * 귀무가설 : 팀 최고 타율과 팀 승률에는 상관관계가 없다.
# * 대립가설 : 팀 최고 타율과 팀 승률에는 상관관계가 있다.

# %%
stats.pearsonr(team_max['타율'],team_max['승률'])
# Out:
# PearsonRResult(statistic=0.19599406877496445, pvalue=0.5873562217801338)

# %% [markdown]
# ### 상관분석의 해석
# * 검정 결과 상관계수는 0.195994이고, p값은 0.58735으로 유의수준 0.05보다 크므로 귀무가설을 기각할 수 없다.
# * 즉, 팀별 최고타율과 팀 승률에는 상관이 없다는 결과에 도달하였다.

# %%
taza_sal_na = taza_sal.dropna(subset=['연봉차'])
taza_sal_na
# Out:
#        이름   팀명     타율  경기수   득점   안타  이루타  삼루타  홈런   타점        Key  \
# 0     이정후   키움  0.349  142   85  193   36   10  23  113     키움_이정후
# 1     피렐라   삼성  0.342  141  102  192   33    4  28  109     삼성_피렐라
# 2     박건우   NC  0.336  111   52  137   18    1  10   61     NC_박건우
# 4     나성범  KIA  0.320  144   92  180   39    2  21   97    KIA_나성범
# 5     김혜성   키움  0.318  129   81  164   18    7   4   48     키움_김혜성
# 6     문보경   LG  0.315  126   52  128   22    3   9   56     LG_문보경
# 7   소크라테스  KIA  0.311  127   83  160   29    7  17   77  KIA_소크라테스
# 9     조용호   KT  0.308  131   52  146   18    4   3   44     KT_조용호
# 10    한동희   롯데  0.307  129   43  140   27    0  14   65     롯데_한동희
# 11    전준우   롯데  0.304  120   73  143   31    1  11   68     롯데_전준우
# 12    최지훈  SSG  0.304  144   93  173   32    4  10   61    SSG_최지훈
# 13    박성한  SSG  0.298  140   68  147   24    4   2   56    SSG_박성한
# 16    박해민   LG  0.289  144   97  165   20    8   3   49     LG_박해민
# ...

# %%
team_taza_tmp['연봉차 평균']=list(taza_sal_na.groupby(['팀명'])['연봉차'].mean())

# %%
team_taza_tmp
# Out:
#     팀명  경기수   승   패  무     승률  연속        홈       원정      평균타율        연봉차 평균
# 0  SSG  144  88  52  4  0.629  4패  49-0-23  39-4-29  0.278200 -13848.285714
# 1   키움  144  80  62  2  0.563  1승  39-1-32  41-1-30  0.291600  21500.000000
# 2   LG  144  87  55  2  0.613  1승  38-1-33  49-1-22  0.285143  -8360.000000
# 3   KT  144  80  62  2  0.563  1패  40-1-31  40-1-31  0.270200 -43666.666667
# 4  KIA  144  70  73  1  0.490  1패  31-0-41  39-1-32  0.278250 -56400.000000
# 5   NC  144  67  74  3  0.475  1패  35-3-34  32-0-40  0.289833   1900.000000
# 6   삼성  144  66  76  2  0.465  2승  33-2-37  33-0-39  0.305000 -15980.000000
# 7   롯데  144  64  76  4  0.457  1승  27-3-42  37-1-34  0.306500  34364.000000
# 8   두산  144  60  82  2  0.423  2패  29-1-42  31-1-40  0.268833  17375.000000
# 9   한화  144  46  96  2  0.324  1패  28-0-44  18-2-52  0.268400  -1467.500000

# %%
fig = plt.figure(figsize=(12, 12))
ax = fig.add_subplot(111)
# 산점도
ax.scatter(team_taza_tmp['승률'],team_taza_tmp['연봉차 평균'])
ax.set_xlabel('팀 승률')
ax.set_ylabel('팀별 연봉차이 평균')
plt.title("팀 승률과 팀별 연봉차이 평균의 산점도")
for i, txt in enumerate(team_taza_tmp['팀명']):
    plt.text(team_taza_tmp['승률'][i], team_taza_tmp['연봉차 평균'][i], txt)
plt.show()
# Out:
# C:\Users\Playdata\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# # 팀별 승률과 타자의 평균 홈런의 상관관계

# %%
taza_sal['홈런'] = taza_sal['홈런'].apply(lambda x : int(x))

# %%
home = taza_sal.groupby(['팀명'])[['홈런']].mean()

# %%
home
# Out:
#             홈런
# 팀명
# KIA  11.625000
# KT   11.600000
# LG   11.571429
# NC   11.500000
# SSG  15.000000
# 두산   11.666667
# 롯데   15.500000
# 삼성   24.500000
# 키움   12.600000
# 한화    7.600000

# %%
team_taza_home = pd.merge(team_taza_tmp,home,left_on = '팀명', right_on = '팀명',how = 'left')
team_taza_home
# Out:
#     팀명  경기수   승   패  무     승률  연속        홈       원정      평균타율        연봉차 평균  \
# 0  SSG  144  88  52  4  0.629  4패  49-0-23  39-4-29  0.278200 -13848.285714
# 1   키움  144  80  62  2  0.563  1승  39-1-32  41-1-30  0.291600  21500.000000
# 2   LG  144  87  55  2  0.613  1승  38-1-33  49-1-22  0.285143  -8360.000000
# 3   KT  144  80  62  2  0.563  1패  40-1-31  40-1-31  0.270200 -43666.666667
# 4  KIA  144  70  73  1  0.490  1패  31-0-41  39-1-32  0.278250 -56400.000000
# 5   NC  144  67  74  3  0.475  1패  35-3-34  32-0-40  0.289833   1900.000000
# 6   삼성  144  66  76  2  0.465  2승  33-2-37  33-0-39  0.305000 -15980.000000
# 7   롯데  144  64  76  4  0.457  1승  27-3-42  37-1-34  0.306500  34364.000000
# 8   두산  144  60  82  2  0.423  2패  29-1-42  31-1-40  0.268833  17375.000000
# 9   한화  144  46  96  2  0.324  1패  28-0-44  18-2-52  0.268400  -1467.500000
#
#           홈런
# 0  15.000000
# 1  12.600000
# 2  11.571429
# 3  11.600000
# 4  11.625000
# 5  11.500000
# 6  24.500000
# 7  15.500000
# ...

# %%
import numpy as np

# %%
data = team_taza_home[['승률','홈런']]

# %%
# 승률과 홈런 평균의 상관계수
data.corr()
# Out:
#           승률        홈런
# 승률  1.000000  0.153586
# 홈런  0.153586  1.000000

# %% [markdown]
# # 승률과 팀별 평균 홈런의 상관분석
# * 귀무가설 : 팀 승률과 팀별 평균 홈런은 상관관계가 없다.
# * 대립가설 : 팀 승률과 팀별 평균 홈런은 상관관계가 있다.

# %%
stats.pearsonr(team_taza_home['홈런'],team_taza_home['승률'])
# Out:
# PearsonRResult(statistic=0.15358561293846984, pvalue=0.6718449452683944)

# %% [markdown]
# ### 상관분석의 해석
# * 팀 승률과 팀별 평균 홈런의 상관분석 결과 상관계수의 값이 0.1535, p값이 0.671로 유의수준 0.05보다 큰 값이므로 귀무가설을 기각할 수 없다.
# * 즉, 팀 승률과 팀별 평균 홈런은 상관관계가 없다라는 결과에 도달

# %% [markdown]
# # 선수별 안타 와 연봉(2023) 의 상관분석
# * 귀무가설 : 선수별 안타와 연봉은 상관관계가 없다.
# * 대립가설 : 선수별 안타와 연봉은 상관관계가 있다.

# %%
taza_sal_na['안타'] = taza_sal_na['안타'].apply(lambda x: int(x))
# Out:
# C:\Users\Playdata\AppData\Local\Temp\ipykernel_7672\3337725151.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   taza_sal_na['안타'] = taza_sal_na['안타'].apply(lambda x: int(x))

# %%
taza_sal_na
# Out:
#        이름   팀명     타율  경기수   득점   안타  이루타  삼루타  홈런   타점        Key  \
# 0     이정후   키움  0.349  142   85  193   36   10  23  113     키움_이정후
# 1     피렐라   삼성  0.342  141  102  192   33    4  28  109     삼성_피렐라
# 2     박건우   NC  0.336  111   52  137   18    1  10   61     NC_박건우
# 4     나성범  KIA  0.320  144   92  180   39    2  21   97    KIA_나성범
# 5     김혜성   키움  0.318  129   81  164   18    7   4   48     키움_김혜성
# 6     문보경   LG  0.315  126   52  128   22    3   9   56     LG_문보경
# 7   소크라테스  KIA  0.311  127   83  160   29    7  17   77  KIA_소크라테스
# 9     조용호   KT  0.308  131   52  146   18    4   3   44     KT_조용호
# 10    한동희   롯데  0.307  129   43  140   27    0  14   65     롯데_한동희
# 11    전준우   롯데  0.304  120   73  143   31    1  11   68     롯데_전준우
# 12    최지훈  SSG  0.304  144   93  173   32    4  10   61    SSG_최지훈
# 13    박성한  SSG  0.298  140   68  147   24    4   2   56    SSG_박성한
# 16    박해민   LG  0.289  144   97  165   20    8   3   49     LG_박해민
# ...

# %%
stats.pearsonr(taza_sal_na['안타'],taza_sal_na['연봉(원화)_2023'])
# Out:
# PearsonRResult(statistic=0.1254189105354499, pvalue=0.4287045519539125)

# %% [markdown]
# ### 상관분석의 해석
# * 선수별 안타와 연봉의 상관분석 결과 상관계수의 값이 0.12541, p값이 0.428704로 유의수준 0.05보다 큰 값이므로 귀무가설을 기각할 수 없다.
# * 즉, 선수별 안타와 연봉은 상관관계가 없다라는 결과에 도달

# %%
taza_sal_na.reset_index(drop=True,inplace = True)

# %%
fig = plt.figure(figsize=(12, 12))
ax = fig.add_subplot(111)
# 산점도
ax.scatter(taza_sal_na['안타'],taza_sal_na['연봉(원화)_2023'])
ax.set_xlabel('안타')
ax.set_ylabel('연봉(2023)')
plt.title("선수별 안타와 연봉(2023)의 산점도")
for i, txt in enumerate(taza_sal_na['이름']):
    plt.text(taza_sal_na['안타'][i], taza_sal_na['연봉(원화)_2023'][i], txt)
plt.show()

# %%
team_taza_mean = pd.merge(team_max,taza_sal.groupby(['팀명'])[['타율']].mean().reset_index(),left_on='팀명',right_on='팀명')
team_taza_mean
# Out:
#     팀명  경기수   승   패  무     승률  연속        홈       원정   타율_x      타율_y
# 0  SSG  144  88  52  4  0.629  4패  49-0-23  39-4-29  0.304  0.278200
# 1   키움  144  80  62  2  0.563  1승  39-1-32  41-1-30  0.349  0.291600
# 2   LG  144  87  55  2  0.613  1승  38-1-33  49-1-22  0.315  0.285143
# 3   KT  144  80  62  2  0.563  1패  40-1-31  40-1-31  0.308  0.270200
# 4  KIA  144  70  73  1  0.490  1패  31-0-41  39-1-32  0.320  0.278250
# 5   NC  144  67  74  3  0.475  1패  35-3-34  32-0-40  0.336  0.289833
# 6   삼성  144  66  76  2  0.465  2승  33-2-37  33-0-39  0.342  0.305000
# 7   롯데  144  64  76  4  0.457  1승  27-3-42  37-1-34  0.331  0.306500
# 8   두산  144  60  82  2  0.423  2패  29-1-42  31-1-40  0.309  0.268833
# 9   한화  144  46  96  2  0.324  1패  28-0-44  18-2-52  0.289  0.268400

# %%
# 마커를 포함한 빨간선 대쉬 선 그래프를 그리고, label은 'red line'으로 설정  
plt.plot(team_taza_mean['팀명'], team_taza_mean['승률'], color='red', marker='o', linestyle='dashed', label='팀 승률')
# X값에 따른 Y값을 나타내는 초록색 막대 그래프를 그리고 label은 'bar plot'으로 설정
plt.plot(team_taza_mean['팀명'],team_taza_mean['타율_y'], color='green', marker='^', linestyle='dashed',label='팀별 타율 평균')
plt.xlabel('팀명')
plt.ylabel('승률과 타율')
# 두개의 그래프에서 label설정된 문자열 값을 범례로 표시
plt.legend()

plt.title('팀 승률과 팀별 타자 타율의 평균')

plt.show()

# %%
fig = plt.figure(figsize=(12, 12))
ax = fig.add_subplot(111)
# 산점도
ax.scatter(team_taza_mean['승률'],team_taza_mean['타율_y'])
ax.set_xlabel('승률')
ax.set_ylabel('팀 평균 타율')
plt.title("팀 승률과 팀 평균 타율의 산점도")
for i, txt in enumerate(team_taza_mean['팀명']):
    plt.text(team_taza_mean['승률'][i], team_taza_mean['타율_y'][i], txt)
plt.show()

# %%
stats.pearsonr(team_taza_mean['승률'],team_taza_mean['타율_y'])
# Out:
# PearsonRResult(statistic=0.09464163633867723, pvalue=0.7948158391290246)

# %% [markdown]
# # 투수 정보 분석하기

# %%
team
# Out:
#     팀명  경기수   승   패  무     승률  연속        홈       원정
# 0  SSG  144  88  52  4  0.629  4패  49-0-23  39-4-29
# 1   키움  144  80  62  2  0.563  1승  39-1-32  41-1-30
# 2   LG  144  87  55  2  0.613  1승  38-1-33  49-1-22
# 3   KT  144  80  62  2  0.563  1패  40-1-31  40-1-31
# 4  KIA  144  70  73  1  0.490  1패  31-0-41  39-1-32
# 5   NC  144  67  74  3  0.475  1패  35-3-34  32-0-40
# 6   삼성  144  66  76  2  0.465  2승  33-2-37  33-0-39
# 7   롯데  144  64  76  4  0.457  1승  27-3-42  37-1-34
# 8   두산  144  60  82  2  0.423  2패  29-1-42  31-1-40
# 9   한화  144  46  96  2  0.324  1패  28-0-44  18-2-52

# %%
tusu_sal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22 entries, 0 to 21
# Data columns (total 23 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   선수명          22 non-null     object
#  1   팀명           22 non-null     object
#  2   평균자책점        22 non-null     object
#  3   경기           22 non-null     object
#  4   승            22 non-null     object
#  5   패            22 non-null     object
#  6   세이브          22 non-null     object
#  7   홀드           22 non-null     object
#  8   승률           22 non-null     object
#  9   이닝           22 non-null     object
#  10  피안타          22 non-null     object
#  11  홈런           22 non-null     object
#  12  볼넷           22 non-null     object
#  13  사구           22 non-null     object
#  14  삼진           22 non-null     object
#  15  실점           22 non-null     object
#  16  자책점          22 non-null     object
#  17  이닝당_출루허용률    22 non-null     object
# ...

# %%
tusu_sal['평균자책점'] = tusu_sal['평균자책점'].apply(lambda x:float(x))
tusu_sal['이닝당_출루허용률'] = tusu_sal['이닝당_출루허용률'].apply(lambda x:float(x))
tusu_sal['승률'] = tusu_sal['승률'].apply(lambda x:float(x))
tusu_sal['경기'] = tusu_sal['경기'].apply(lambda x:int(x))
tusu_sal['승'] = tusu_sal['승'].apply(lambda x:int(x))
tusu_sal['패'] = tusu_sal['패'].apply(lambda x:int(x))
tusu_sal['세이브'] = tusu_sal['세이브'].apply(lambda x:int(x))
tusu_sal['피안타'] = tusu_sal['피안타'].apply(lambda x:int(x))
tusu_sal['홈런'] = tusu_sal['홈런'].apply(lambda x:int(x))
tusu_sal['사구'] = tusu_sal['사구'].apply(lambda x:int(x))
tusu_sal['삼진'] = tusu_sal['삼진'].apply(lambda x:int(x))
tusu_sal['실점'] = tusu_sal['실점'].apply(lambda x:int(x))
tusu_sal['자책점'] = tusu_sal['자책점'].apply(lambda x:int(x))

# %%
tusu_sal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22 entries, 0 to 21
# Data columns (total 23 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   선수명          22 non-null     object
#  1   팀명           22 non-null     object
#  2   평균자책점        22 non-null     float64
#  3   경기           22 non-null     int64
#  4   승            22 non-null     int64
#  5   패            22 non-null     int64
#  6   세이브          22 non-null     int64
#  7   홀드           22 non-null     object
#  8   승률           22 non-null     float64
#  9   이닝           22 non-null     object
#  10  피안타          22 non-null     int64
#  11  홈런           22 non-null     int64
#  12  볼넷           22 non-null     object
#  13  사구           22 non-null     int64
#  14  삼진           22 non-null     int64
#  15  실점           22 non-null     int64
#  16  자책점          22 non-null     int64
#  17  이닝당_출루허용률    22 non-null     float64
# ...

# %%
# 팀별 각 투수의 승률 평균
tusu_sal.groupby(['팀명'])[['승률']].mean().reset_index()
# Out:
#     팀명        승률
# 0  KIA  0.566000
# 1   KT  0.567667
# 2   LG  0.775000
# 3   NC  0.455000
# 4  SSG  0.642000
# 5   두산  0.442000
# 6   롯데  0.488000
# 7   삼성  0.521333
# 8   키움  0.604000
# 9   한화  0.353000

# %%
team_max
# Out:
#     팀명  경기수   승   패  무     승률  연속        홈       원정     타율
# 0  SSG  144  88  52  4  0.629  4패  49-0-23  39-4-29  0.304
# 1   키움  144  80  62  2  0.563  1승  39-1-32  41-1-30  0.349
# 2   LG  144  87  55  2  0.613  1승  38-1-33  49-1-22  0.315
# 3   KT  144  80  62  2  0.563  1패  40-1-31  40-1-31  0.308
# 4  KIA  144  70  73  1  0.490  1패  31-0-41  39-1-32  0.320
# 5   NC  144  67  74  3  0.475  1패  35-3-34  32-0-40  0.336
# 6   삼성  144  66  76  2  0.465  2승  33-2-37  33-0-39  0.342
# 7   롯데  144  64  76  4  0.457  1승  27-3-42  37-1-34  0.331
# 8   두산  144  60  82  2  0.423  2패  29-1-42  31-1-40  0.309
# 9   한화  144  46  96  2  0.324  1패  28-0-44  18-2-52  0.289

# %% [markdown]
# # 팀 승률과 팀별 투수 승률의 평균

# %% [markdown]
# # 팀 승률 과 팀별 투수 승률의 평균 의 상관분석
# * 귀무가설 : 팀 승률과 투수 승률의 평균은 상관관계가 없다.
# * 대립가설 :  팀 승률과 투수 승률의 평균은 상관관계가 있다.

# %%
team_tusu_win = pd.merge(team_max,tusu_sal.groupby(['팀명'])[['승률']].mean().reset_index(),left_on='팀명',right_on='팀명')
team_tusu_win
# Out:
#     팀명  경기수   승   패  무   승률_x  연속        홈       원정     타율      승률_y
# 0  SSG  144  88  52  4  0.629  4패  49-0-23  39-4-29  0.304  0.642000
# 1   키움  144  80  62  2  0.563  1승  39-1-32  41-1-30  0.349  0.604000
# 2   LG  144  87  55  2  0.613  1승  38-1-33  49-1-22  0.315  0.775000
# 3   KT  144  80  62  2  0.563  1패  40-1-31  40-1-31  0.308  0.567667
# 4  KIA  144  70  73  1  0.490  1패  31-0-41  39-1-32  0.320  0.566000
# 5   NC  144  67  74  3  0.475  1패  35-3-34  32-0-40  0.336  0.455000
# 6   삼성  144  66  76  2  0.465  2승  33-2-37  33-0-39  0.342  0.521333
# 7   롯데  144  64  76  4  0.457  1승  27-3-42  37-1-34  0.331  0.488000
# 8   두산  144  60  82  2  0.423  2패  29-1-42  31-1-40  0.309  0.442000
# 9   한화  144  46  96  2  0.324  1패  28-0-44  18-2-52  0.289  0.353000

# %%
# 마커를 포함한 빨간선 대쉬 선 그래프를 그리고, label은 'red line'으로 설정  
plt.plot(team_tusu_win['팀명'], team_tusu_win['승률_x'], color='red', marker='o', linestyle='dashed', label='팀 승률')
# X값에 따른 Y값을 나타내는 초록색 막대 그래프를 그리고 label은 'bar plot'으로 설정
plt.bar(team_tusu_win['팀명'],team_tusu_win['승률_y'], color='green', label='투수 승률의 평균')
plt.xlabel('팀명')
plt.ylabel('승률')
# 두개의 그래프에서 label설정된 문자열 값을 범례로 표시
plt.legend()

plt.title('팀 승률과 팀별 투수 승률의 평균')

plt.show()

# %%
stats.pearsonr(team_tusu_win['승률_x'],team_tusu_win['승률_y'])
# Out:
# PearsonRResult(statistic=0.9145847815736182, pvalue=0.0002098430215114219)

# %%
fig = plt.figure(figsize=(12, 12))
ax = fig.add_subplot(111)
# 산점도
ax.scatter(team_tusu_win['승률_x'],team_tusu_win['승률_y'])
ax.set_xlabel('팀 승률')
ax.set_ylabel('팀별 투수 평균 승률')
plt.title("팀 승률과 팀별 투수 승률의 평균")
for i, txt in enumerate(team_tusu_win['팀명']):
    plt.text(team_tusu_win['승률_x'][i], team_tusu_win['승률_y'][i], txt)
plt.show()

# %% [markdown]
# ### 상관분석의 해석
# * 팀 승률과 팀별 투수 평균 승률의 상관분석 결과 상관계수의 값이 0.914584, p값이 0.0002로 유의수준 0.05보다 작은 값이므로 귀무가설을 기각할 수 있다.
# * 즉, 팀 승률과 팀별 투수 평균 승률은 강한 양의 상관관계가 있다라는 결과에 도달

# %%
# 팀별 투수의 삼진 평균
tusu_sal.groupby(['팀명'])[['삼진']].mean()
# Out:
#              삼진
# 팀명
# KIA  151.000000
# KT   132.000000
# LG   151.000000
# NC   194.000000
# SSG  145.000000
# 두산   129.666667
# 롯데   153.000000
# 삼성   135.333333
# 키움   189.000000
# 한화   129.000000

# %%
# 팀별 평균자책점이 가장 높은 값들
tusu_sal.groupby(['팀명'])[['평균자책점']].max()
# Out:
#      평균자책점
# 팀명
# KIA   3.86
# KT    4.53
# LG    2.54
# NC    2.97
# SSG   4.50
# 두산    3.78
# 롯데    3.89
# 삼성    3.92
# 키움    2.57
# 한화    4.36

# %% [markdown]
# # 팀 별 투수 평균 승률과 팀별 타자 평균 타율의 상관분석

# %%
tusu_sal.groupby(['팀명'])[['승률']].mean()
# Out:
#            승률
# 팀명
# KIA  0.566000
# KT   0.567667
# LG   0.775000
# NC   0.455000
# SSG  0.642000
# 두산   0.442000
# 롯데   0.488000
# 삼성   0.521333
# 키움   0.604000
# 한화   0.353000

# %%
taza_sal.groupby(['팀명'])[['타율']].mean()
# Out:
#            타율
# 팀명
# KIA  0.278250
# KT   0.270200
# LG   0.285143
# NC   0.289833
# SSG  0.278200
# 두산   0.268833
# 롯데   0.306500
# 삼성   0.305000
# 키움   0.291600
# 한화   0.268400

# %%
taza_tusu_mean = pd.merge(taza_sal.groupby(['팀명'])[['타율']].mean().reset_index(),tusu_sal.groupby(['팀명'])[['승률']].mean().reset_index(),left_on = '팀명',right_on = '팀명')
taza_tusu_mean
# Out:
#     팀명        타율        승률
# 0  KIA  0.278250  0.566000
# 1   KT  0.270200  0.567667
# 2   LG  0.285143  0.775000
# 3   NC  0.289833  0.455000
# 4  SSG  0.278200  0.642000
# 5   두산  0.268833  0.442000
# 6   롯데  0.306500  0.488000
# 7   삼성  0.305000  0.521333
# 8   키움  0.291600  0.604000
# 9   한화  0.268400  0.353000

# %%
# 마커를 포함한 빨간선 대쉬 선 그래프를 그리고, label은 'red line'으로 설정  
plt.plot(taza_tusu_mean['팀명'],taza_tusu_mean['타율'] , color='red', marker='o', linestyle='dashed', label='팀 평균 타율')
# X값에 따른 Y값을 나타내는 초록색 막대 그래프를 그리고 label은 'bar plot'으로 설정
plt.bar(taza_tusu_mean['팀명'],taza_tusu_mean['승률'], color='green', label='투수 승률의 평균')
plt.xlabel('팀명')
plt.ylabel('팀 평균 타율 및 승률')
# 두개의 그래프에서 label설정된 문자열 값을 범례로 표시
plt.legend()

plt.title('팀별 평균 타율과 팀별 투수 승률의 평균')

plt.show()

# %%
stats.pearsonr(taza_tusu_mean['타율'],taza_tusu_mean['승률'])
# Out:
# PearsonRResult(statistic=0.13223484593608298, pvalue=0.7157415091854578)

# %% [markdown]
# # 팀별 타자 평균연봉과 팀 승률의 상관분석

# %%
team_max['승률']
# Out:
# 0    0.629
# 1    0.563
# 2    0.613
# 3    0.563
# 4    0.490
# 5    0.475
# 6    0.465
# 7    0.457
# 8    0.423
# 9    0.324
# Name: 승률, dtype: float64

# %%
taza_sal.groupby('팀명')[['연봉(원화)_2022']].mean().reset_index()
# Out:
#     팀명    연봉(원화)_2022
# 0  KIA   60354.714286
# 1   KT   35200.000000
# 2   LG   51971.428571
# 3   NC   92577.500000
# 4  SSG  131800.000000
# 5   두산   75113.333333
# 6   롯데   61800.000000
# 7   삼성   65090.000000
# 8   키움   45275.200000
# 9   한화   27729.200000

# %%
taza_money = pd.merge(team_max,taza_sal.groupby('팀명')[['연봉(원화)_2022']].mean().reset_index(),left_on = '팀명',right_on = '팀명')
taza_money
# Out:
#     팀명  경기수   승   패  무     승률  연속        홈       원정     타율    연봉(원화)_2022
# 0  SSG  144  88  52  4  0.629  4패  49-0-23  39-4-29  0.304  131800.000000
# 1   키움  144  80  62  2  0.563  1승  39-1-32  41-1-30  0.349   45275.200000
# 2   LG  144  87  55  2  0.613  1승  38-1-33  49-1-22  0.315   51971.428571
# 3   KT  144  80  62  2  0.563  1패  40-1-31  40-1-31  0.308   35200.000000
# 4  KIA  144  70  73  1  0.490  1패  31-0-41  39-1-32  0.320   60354.714286
# 5   NC  144  67  74  3  0.475  1패  35-3-34  32-0-40  0.336   92577.500000
# 6   삼성  144  66  76  2  0.465  2승  33-2-37  33-0-39  0.342   65090.000000
# 7   롯데  144  64  76  4  0.457  1승  27-3-42  37-1-34  0.331   61800.000000
# 8   두산  144  60  82  2  0.423  2패  29-1-42  31-1-40  0.309   75113.333333
# 9   한화  144  46  96  2  0.324  1패  28-0-44  18-2-52  0.289   27729.200000

# %%
fig = plt.figure(figsize=(12, 12))
ax = fig.add_subplot(111)
# 산점도
ax.scatter(taza_money['승률'],taza_money['연봉(원화)_2022'])
ax.set_xlabel('팀 승률')
ax.set_ylabel('타자 평균 연봉')
plt.title("팀 승률과 타자 평균 연봉의 산점도")
for i, txt in enumerate(taza_money['팀명']):
    plt.text(taza_money['승률'][i], taza_money['연봉(원화)_2022'][i], txt)
plt.show()

# %%
stats.pearsonr(taza_money['승률'],taza_money['연봉(원화)_2022'])
# Out:
# PearsonRResult(statistic=0.3677083899289719, pvalue=0.29585628475131015)

# %%
tusu_money = pd.merge(team_max,tusu_sal.groupby('팀명')[['연봉(원화)_2022']].mean().reset_index(),left_on = '팀명',right_on = '팀명')
tusu_money
# Out:
#     팀명  경기수   승   패  무     승률  연속        홈       원정     타율    연봉(원화)_2022
# 0  SSG  144  88  52  4  0.629  4패  49-0-23  39-4-29  0.304  315054.333333
# 1   키움  144  80  62  2  0.563  1승  39-1-32  41-1-30  0.349   60135.000000
# 2   LG  144  87  55  2  0.613  1승  38-1-33  49-1-22  0.315   81876.500000
# 3   KT  144  80  62  2  0.563  1패  40-1-31  40-1-31  0.308   43958.666667
# 4  KIA  144  70  73  1  0.490  1패  31-0-41  39-1-32  0.320   54500.000000
# 5   NC  144  67  74  3  0.475  1패  35-3-34  32-0-40  0.336  187147.000000
# 6   삼성  144  66  76  2  0.465  2승  33-2-37  33-0-39  0.342   80179.666667
# 7   롯데  144  64  76  4  0.457  1승  27-3-42  37-1-34  0.331   40217.000000
# 8   두산  144  60  82  2  0.423  2패  29-1-42  31-1-40  0.309   29095.333333
# 9   한화  144  46  96  2  0.324  1패  28-0-44  18-2-52  0.289   19100.000000

# %%
fig = plt.figure(figsize=(12, 12))
ax = fig.add_subplot(111)
# 산점도
ax.scatter(tusu_money['승률'],tusu_money['연봉(원화)_2022'])
ax.set_xlabel('팀 승률')
ax.set_ylabel('투수 평균 연봉')
plt.title("팀 승률과 투수 평균 연봉의 산점도")
for i, txt in enumerate(tusu_money['팀명']):
    plt.text(tusu_money['승률'][i], tusu_money['연봉(원화)_2022'][i], txt)
plt.show()

# %%
stats.pearsonr(tusu_money['승률'],tusu_money['연봉(원화)_2022'])
# Out:
# PearsonRResult(statistic=0.532117683452455, pvalue=0.11336174068245394)

# %% [markdown]
# # 투수 승률 과  투수 자책점 의 상관분석
# * 귀무가설 : 투수 승률과 투수 자책점은 상관관계가 없다.
# * 대립가설 :  투수 승률과 투수 자책점은 상관관계가 있다.

# %%
fig = plt.figure(figsize=(12, 12))
ax = fig.add_subplot(111)
# 산점도
ax.scatter(tusu_sal['승률'],tusu_sal['자책점'])
ax.set_xlabel('투수 승률')
ax.set_ylabel('투수 자책점')
plt.title("투수 승률과 투수 자책점의 산점도")
for i, txt in enumerate(tusu_sal['팀명']):
    plt.text(tusu_sal['승률'][i], tusu_sal['자책점'][i], txt)
plt.show()

# %%
stats.pearsonr(tusu_sal['승률'],tusu_sal['자책점'])
# Out:
# PearsonRResult(statistic=-0.6893533273182396, pvalue=0.00038698174628620146)

# %% [markdown]
# # 투수 승률 과  투수 이닝당 출루허용률 의 상관분석
# * 귀무가설 : 투수 승률과 투수 이닝당 출루허용률은 상관관계가 없다.
# * 대립가설 :  투수 승률과 투수 이닝당 출루허용률은 상관관계가 있다.

# %%
plt.figure(figsize=(20, 12))
# 마커를 포함한 빨간선 대쉬 선 그래프를 그리고, label은 'red line'으로 설정  
plt.plot(tusu_sal['선수명'],tusu_sal['승률'] , color='red', marker='o', linestyle='dashed', label='투수 승률')
# X값에 따른 Y값을 나타내는 초록색 막대 그래프를 그리고 label은 'bar plot'으로 설정
plt.plot(tusu_sal['선수명'],tusu_sal['이닝당_출루허용률'], color='green',marker='^', linestyle='dashed', label='투수 이닝당 출루 허용률')
plt.xlabel('이름')
plt.ylabel('투수 승률 및 이닝당 출루 허용률')
# 두개의 그래프에서 label설정된 문자열 값을 범례로 표시
plt.legend()

plt.title('투수 승률과 이닝당 출루 허용률')

plt.show()

# %%
stats.pearsonr(tusu_sal['승률'],tusu_sal['이닝당_출루허용률'])
# Out:
# PearsonRResult(statistic=-0.722675395062331, pvalue=0.00014533486833129202)

# %%
tusu_sal
# Out:
#       선수명   팀명  평균자책점  경기   승   패  세이브 홀드     승률       이닝  ...  사구   삼진  실점  \
# 0     안우진   키움   2.11  30  15   8    0  0  0.652      196  ...   4  224  51
# 1     김광현  SSG   2.13  28  13   3    0  0  0.813  173 1/3  ...   5  153  48
# 2     플럿코   LG   2.39  28  15   5    0  0  0.750      162  ...   2  149  53
# 3    수아레즈   삼성   2.49  30   6   8    0  0  0.429  173 2/3  ...   4  159  61
# 4      켈리   LG   2.54  27  16   4    0  0  0.800  166 1/3  ...   2  153  50
# 5     요키시   키움   2.57  30  10   8    0  0  0.556  185 1/3  ...   5  154  61
# 6      폰트  SSG   2.69  28  13   6    0  0  0.684      184  ...   6  170  63
# 7    루친스키   NC   2.97  31  10  12    0  0  0.455  193 2/3  ...   8  194  77
# 8     뷰캐넌   삼성   3.04  26  11   8    0  0  0.579      160  ...   8  117  61
# 9     소형준   KT   3.05  27  13   6    0  0  0.684  171 1/3  ...   5  117  68
# 10    고영표   KT   3.26  28  13   8    0  0  0.619  182 1/3  ...  16  156  69
# ...

# %%
tusu_sal[['평균자책점','승률','사구','삼진','자책점','이닝당_출루허용률']].corr()
# Out:
#               평균자책점        승률        사구        삼진       자책점  이닝당_출루허용률
# 평균자책점      1.000000 -0.699714  0.320227 -0.579498  0.933262   0.876535
# 승률        -0.699714  1.000000 -0.359094  0.277167 -0.689353  -0.722675
# 사구         0.320227 -0.359094  1.000000  0.024909  0.449587   0.273969
# 삼진        -0.579498  0.277167  0.024909  1.000000 -0.405528  -0.682257
# 자책점        0.933262 -0.689353  0.449587 -0.405528  1.000000   0.735100
# 이닝당_출루허용률  0.876535 -0.722675  0.273969 -0.682257  0.735100   1.000000

# %%
taza_sal[['타율','득점','안타','이루타','삼루타','홈런','타점']].corr()
# Out:
#            타율        득점        안타       이루타       삼루타        홈런        타점
# 타율   1.000000  0.335192  0.825144  0.417215  0.388553  0.111273  0.353135
# 득점   0.335192  1.000000  0.570683  0.314268  0.531577  0.259933  0.195777
# 안타   0.825144  0.570683  1.000000  0.577378  0.531918  0.146324  0.402852
# 이루타  0.417215  0.314268  0.577378  1.000000  0.041297  0.352523  0.540873
# 삼루타  0.388553  0.531577  0.531918  0.041297  1.000000 -0.169416 -0.069287
# 홈런   0.111273  0.259933  0.146324  0.352523 -0.169416  1.000000  0.811037
# 타점   0.353135  0.195777  0.402852  0.540873 -0.069287  0.811037  1.000000

# %%
taza_sal['일루타'] = taza_sal['안타']-(taza_sal['이루타']+taza_sal['삼루타']+taza_sal['홈런'])
taza_sal['이루타율'] = taza_sal['이루타'] / taza_sal['안타']
taza_sal['일루타율'] = taza_sal['일루타'] / taza_sal['안타']
taza_sal['삼루타율'] = taza_sal['삼루타'] / taza_sal['안타']
taza_sal['홈런율'] = taza_sal['홈런'] / taza_sal['안타']

# %%
taza_sal.head(1)
# Out:
#     이름  팀명     타율  경기수  득점   안타  이루타  삼루타  홈런   타점     Key  \
# 0  이정후  키움  0.349  142  85  193   36   10  23  113  키움_이정후
#
#                    경력  연봉(원화)_2022  연봉(원화)_2023      연봉차  일루타      이루타율  \
# 0  광주서석초-휘문중-휘문고-히어로즈      75000.0     110000.0  35000.0  124  0.186528
#
#        일루타율      삼루타율       홈런율
# 0  0.642487  0.051813  0.119171

# %%
stats.pearsonr(taza_sal['일루타율'],taza_sal['홈런율'])
# Out:
# PearsonRResult(statistic=-0.8890524919338495, pvalue=6.161290642972242e-19)

# %%
plt.figure(figsize=(20, 12))
# 마커를 포함한 빨간선 대쉬 선 그래프를 그리고, label은 'red line'으로 설정  
plt.plot(taza_sal['이름'],taza_sal['일루타율'] , color='red', marker='o', linestyle='dashed', label='타자 일루타율')
# X값에 따른 Y값을 나타내는 초록색 막대 그래프를 그리고 label은 'bar plot'으로 설정
plt.plot(taza_sal['이름'],taza_sal['홈런율'], color='green',marker='^', linestyle='dashed', label='타자 홈런율')
plt.xlabel('이름')
plt.ylabel('일루타율 및 홈런률')
# 두개의 그래프에서 label설정된 문자열 값을 범례로 표시
plt.legend()

plt.title('일루타율과 홈런률')

plt.show()

# %%
fig = plt.figure(figsize=(12, 12))
ax = fig.add_subplot(111)
# 산점도
ax.scatter(taza_sal['일루타율'],taza_sal['홈런율'])
ax.set_xlabel('일루타율')
ax.set_ylabel('홈런율')
plt.title("일루타율과 홈런율의 산점도")
for i, txt in enumerate(taza_sal['이름']):
    plt.text(taza_sal['일루타율'][i], taza_sal['홈런율'][i], txt)
plt.show()

# %%
plt.figure(figsize=(20, 12))
# 마커를 포함한 빨간선 대쉬 선 그래프를 그리고, label은 'red line'으로 설정  
plt.plot(taza_sal['이름'],taza_sal['이루타율'] , color='red', marker='o', linestyle='dashed', label='타자 이루타율')
# X값에 따른 Y값을 나타내는 초록색 막대 그래프를 그리고 label은 'bar plot'으로 설정
plt.plot(taza_sal['이름'],taza_sal['홈런율'], color='green',marker='^', linestyle='dashed', label='타자 홈런율')
plt.xlabel('이름')
plt.ylabel('이루타율 및 홈런률')
# 두개의 그래프에서 label설정된 문자열 값을 범례로 표시
plt.legend()

plt.title('이루타율과 홈런률')

plt.show()

# %%
fig = plt.figure(figsize=(12, 12))
ax = fig.add_subplot(111)
# 산점도
ax.scatter(taza_sal['이루타율'],taza_sal['홈런율'])
ax.set_xlabel('이루타율')
ax.set_ylabel('홈런율')
plt.title("이루타율과 홈런율의 산점도")
for i, txt in enumerate(taza_sal['이름']):
    plt.text(taza_sal['이루타율'][i], taza_sal['홈런율'][i], txt)
plt.show()

# %%
stats.pearsonr(taza_sal['이루타율'],taza_sal['홈런율'])
# Out:
# PearsonRResult(statistic=0.34536418735058866, pvalue=0.011315618701714693)

# %%
plt.figure(figsize=(20, 12))
# 마커를 포함한 빨간선 대쉬 선 그래프를 그리고, label은 'red line'으로 설정  
plt.plot(taza_sal['이름'],taza_sal['삼루타율'] , color='red', marker='o', linestyle='dashed', label='타자 삼루타율')
# X값에 따른 Y값을 나타내는 초록색 막대 그래프를 그리고 label은 'bar plot'으로 설정
plt.plot(taza_sal['이름'],taza_sal['홈런율'], color='green',marker='^', linestyle='dashed', label='타자 홈런율')
plt.xlabel('이름')
plt.ylabel('삼루타율 및 홈런률')
# 두개의 그래프에서 label설정된 문자열 값을 범례로 표시
plt.legend()

plt.title('삼루타율과 홈런률')

plt.show()

# %%
fig = plt.figure(figsize=(12, 12))
ax = fig.add_subplot(111)
# 산점도
ax.scatter(taza_sal['삼루타율'],taza_sal['홈런율'])
ax.set_xlabel('삼루타율')
ax.set_ylabel('홈런율')
plt.title("삼루타율과 홈런율의 산점도")
for i, txt in enumerate(taza_sal['이름']):
    plt.text(taza_sal['삼루타율'][i], taza_sal['홈런율'][i], txt)
plt.show()

# %%
stats.pearsonr(taza_sal['삼루타율'],taza_sal['홈런율'])
# Out:
# PearsonRResult(statistic=-0.38969991151132444, pvalue=0.003921677353487378)

# %%
taza_sal
# Out:
#        이름   팀명     타율  경기수   득점   안타  이루타  삼루타  홈런   타점        Key  \
# 0     이정후   키움  0.349  142   85  193   36   10  23  113     키움_이정후
# 1     피렐라   삼성  0.342  141  102  192   33    4  28  109     삼성_피렐라
# 2     박건우   NC  0.336  111   52  137   18    1  10   61     NC_박건우
# 3     이대호   롯데  0.331  142   53  179   23    0  23  101     롯데_이대호
# 4     나성범  KIA  0.320  144   92  180   39    2  21   97    KIA_나성범
# 5     김혜성   키움  0.318  129   81  164   18    7   4   48     키움_김혜성
# 6     문보경   LG  0.315  126   52  128   22    3   9   56     LG_문보경
# 7   소크라테스  KIA  0.311  127   83  160   29    7  17   77  KIA_소크라테스
# 8   페르난데스   두산  0.309  139   52  157   28    0   6   77   두산_페르난데스
# 9     조용호   KT  0.308  131   52  146   18    4   3   44     KT_조용호
# 10    한동희   롯데  0.307  129   43  140   27    0  14   65     롯데_한동희
# 11    전준우   롯데  0.304  120   73  143   31    1  11   68     롯데_전준우
# 12    최지훈  SSG  0.304  144   93  173   32    4  10   61    SSG_최지훈
# ...

# %%
taza_salary = list(taza_sal['연봉(원화)_2022'].dropna())
taza_salary
# Out:
# [75000.0,
#  70180.0,
#  190000.0,
#  80000.0,
#  200000.0,
#  32000.0,
#  6800.0,
#  58483.0,
#  70180.0,
#  24000.0,
#  17200.0,
#  50000.0,
#  15000.0,
#  14000.0,
#  51465.0,
#  28000.0,
#  60000.0,
#  120000.0,
#  81876.0,
#  45000.0,
#  150000.0,
#  32000.0,
#  100000.0,
#  100000.0,
#  12000.0,
#  23000.0,
#  150000.0,
#  81876.0,
#  60000.0,
#  10500.0,
#  19080.0,
#  12000.0,
#  60000.0,
#  60000.0,
#  30000.0,
#  41000.0,
#  26000.0,
#  120000.0,
#  90000.0,
#  240000.0,
#  11500.0,
#  40000.0,
#  60000.0,
#  270000.0,
#  20090.0,
#  6500.0,
#  27000.0,
#  150000.0,
#  7500.0,
#  39000.0,
#  5600.0,
#  26000.0]

# %%
tusu_salary = list(tusu_sal['연봉(원화)_2022'].dropna())
tusu_salary
# Out:
# [15000.0,
#  810000.0,
#  58483.0,
#  81876.0,
#  105270.0,
#  105270.0,
#  128663.0,
#  187147.0,
#  128663.0,
#  20000.0,
#  30000.0,
#  46786.0,
#  34000.0,
#  54434.0,
#  6500.0,
#  100000.0,
#  9000.0,
#  26000.0,
#  30000.0,
#  19100.0,
#  6500.0,
#  81876.0]

# %%
sum(taza_salary)/len(taza_salary)
# Out:
# 64804.42307692308

# %%
sum(tusu_salary)/len(tusu_salary)
# Out:
# 94753.09090909091

# %%
# 타자 평균 연봉과 투수 평균 연봉의 등분산 검정
from scipy.stats import bartlett
bartlett(taza_salary, tusu_salary)
# p값이 매우 작으므로 귀무가설을 기각한다. 즉, 등분산이 아니다.
# Out:
# BartlettResult(statistic=33.51151630715792, pvalue=7.084328265365405e-09)

# %%
# 타자 평균 연봉과 투수 평균 연봉의 t-test
# 귀무가설 : 타자 평균 연봉과 투수 평균 연봉은 같다.
# 대립가설 : 타자 평균 연봉과 투수 평균 연봉은 같지 않다.
import scipy.stats

scipy.stats.ttest_ind(taza_salary, tusu_salary, equal_var=False)
# p값이 0.05보다 크므로 귀무가설을 기각할 수 없다. 즉 차이가 없다라고 할 수 있다.
# Out:
# Ttest_indResult(statistic=-0.8183109786758093, pvalue=0.4214297255981392)

# %%
tusu_sal.groupby(['팀명'])[['삼진']].mean()
# Out:
#              삼진
# 팀명
# KIA  151.000000
# KT   132.000000
# LG   151.000000
# NC   194.000000
# SSG  145.000000
# 두산   129.666667
# 롯데   153.000000
# 삼성   135.333333
# 키움   189.000000
# 한화   129.000000

# %%
team_max
# Out:
#     팀명  경기수   승   패  무     승률  연속        홈       원정     타율
# 0  SSG  144  88  52  4  0.629  4패  49-0-23  39-4-29  0.304
# 1   키움  144  80  62  2  0.563  1승  39-1-32  41-1-30  0.349
# 2   LG  144  87  55  2  0.613  1승  38-1-33  49-1-22  0.315
# 3   KT  144  80  62  2  0.563  1패  40-1-31  40-1-31  0.308
# 4  KIA  144  70  73  1  0.490  1패  31-0-41  39-1-32  0.320
# 5   NC  144  67  74  3  0.475  1패  35-3-34  32-0-40  0.336
# 6   삼성  144  66  76  2  0.465  2승  33-2-37  33-0-39  0.342
# 7   롯데  144  64  76  4  0.457  1승  27-3-42  37-1-34  0.331
# 8   두산  144  60  82  2  0.423  2패  29-1-42  31-1-40  0.309
# 9   한화  144  46  96  2  0.324  1패  28-0-44  18-2-52  0.289

# %%
tusu_samgin = pd.merge(team_max,tusu_sal.groupby(['팀명'])[['삼진']].mean().reset_index(),left_on = '팀명',right_on='팀명')
tusu_samgin
# Out:
#     팀명  경기수   승   패  무     승률  연속        홈       원정     타율          삼진
# 0  SSG  144  88  52  4  0.629  4패  49-0-23  39-4-29  0.304  145.000000
# 1   키움  144  80  62  2  0.563  1승  39-1-32  41-1-30  0.349  189.000000
# 2   LG  144  87  55  2  0.613  1승  38-1-33  49-1-22  0.315  151.000000
# 3   KT  144  80  62  2  0.563  1패  40-1-31  40-1-31  0.308  132.000000
# 4  KIA  144  70  73  1  0.490  1패  31-0-41  39-1-32  0.320  151.000000
# 5   NC  144  67  74  3  0.475  1패  35-3-34  32-0-40  0.336  194.000000
# 6   삼성  144  66  76  2  0.465  2승  33-2-37  33-0-39  0.342  135.333333
# 7   롯데  144  64  76  4  0.457  1승  27-3-42  37-1-34  0.331  153.000000
# 8   두산  144  60  82  2  0.423  2패  29-1-42  31-1-40  0.309  129.666667
# 9   한화  144  46  96  2  0.324  1패  28-0-44  18-2-52  0.289  129.000000

# %%
stats.pearsonr(tusu_samgin['승률'],tusu_samgin['삼진'])
# Out:
# PearsonRResult(statistic=0.27290019239456265, pvalue=0.44553840870667766)

# %%
tusu_sal.head(1)
# Out:
#    선수명  팀명  평균자책점  경기   승  패  세이브 홀드     승률   이닝  ...  사구   삼진  실점  자책점  \
# 0  안우진  키움   2.11  30  15  8    0  0  0.652  196  ...   4  224  51   46
#
#    이닝당_출루허용률     Key  연봉(원화)_2022          경력 연봉(원화)_2023      연봉차
# 0       0.95  키움_안우진      15000.0   강남초-서울이수중     35000.0  20000.0
#
# [1 rows x 23 columns]

# %% [markdown]
# # 팀 승률 과  투수 평균자책점 의 상관분석
# * 귀무가설 : 팀 승률과 투수 평균자책점은 상관관계가 없다.
# * 대립가설 :  팀 승률과 투수 평균자책점은 상관관계가 있다.

# %%
tusu_shit = pd.merge(team_max,tusu_sal.groupby(['팀명'])[['평균자책점']].mean().reset_index(),left_on = '팀명',right_on='팀명')
tusu_shit
# Out:
#     팀명  경기수   승   패  무     승률  연속        홈       원정     타율     평균자책점
# 0  SSG  144  88  52  4  0.629  4패  49-0-23  39-4-29  0.304  3.106667
# 1   키움  144  80  62  2  0.563  1승  39-1-32  41-1-30  0.349  2.340000
# 2   LG  144  87  55  2  0.613  1승  38-1-33  49-1-22  0.315  2.465000
# 3   KT  144  80  62  2  0.563  1패  40-1-31  40-1-31  0.308  3.613333
# 4  KIA  144  70  73  1  0.490  1패  31-0-41  39-1-32  0.320  3.855000
# 5   NC  144  67  74  3  0.475  1패  35-3-34  32-0-40  0.336  2.970000
# 6   삼성  144  66  76  2  0.465  2승  33-2-37  33-0-39  0.342  3.150000
# 7   롯데  144  64  76  4  0.457  1승  27-3-42  37-1-34  0.331  3.755000
# 8   두산  144  60  82  2  0.423  2패  29-1-42  31-1-40  0.309  3.660000
# 9   한화  144  46  96  2  0.324  1패  28-0-44  18-2-52  0.289  4.360000

# %%
fig = plt.figure(figsize=(12, 12))
ax = fig.add_subplot(111)
# 산점도
ax.scatter(tusu_shit['승률'],tusu_shit['평균자책점'])
ax.set_xlabel('승률')
ax.set_ylabel('평균자책점')
plt.title("승률과 평균자책점의 산점도")
for i, txt in enumerate(tusu_shit['팀명']):
    plt.text(tusu_shit['승률'][i], tusu_shit['평균자책점'][i], txt)
plt.show()

# %%
stats.pearsonr(tusu_shit['승률'],tusu_shit['평균자책점'])
# Out:
# PearsonRResult(statistic=-0.7235079637962233, pvalue=0.01802397861071952)

# %% [markdown]
# ### 상관분석의 해석
# * 팀 승률과 투수 평균자책점의 상관분석 결과 상관계수의 값이 -0.7235, p값이 0.01802로 유의수준 0.05보다 작은 값이므로 귀무가설을 기각할 수 있다.
# * 즉, 팀 승률과 투수 평균자책점은 강한 음의 상관관계가 있다라는 결과에 도달

# %%
tusu_sal.groupby(['팀명'])[['피안타']].mean().reset_index()
# Out:
#     팀명         피안타
# 0  KIA  149.000000
# 1   KT  182.333333
# 2   LG  134.500000
# 3   NC  184.000000
# 4  SSG  146.666667
# 5   두산  162.666667
# 6   롯데  177.500000
# 7   삼성  167.333333
# 8   키움  150.000000
# 9   한화  143.000000

# %%
tusu_pi = pd.merge(team_max,tusu_sal.groupby(['팀명'])[['피안타']].mean().reset_index(),left_on = '팀명',right_on = '팀명')
tusu_pi
# Out:
#     팀명  경기수   승   패  무     승률  연속        홈       원정     타율         피안타
# 0  SSG  144  88  52  4  0.629  4패  49-0-23  39-4-29  0.304  146.666667
# 1   키움  144  80  62  2  0.563  1승  39-1-32  41-1-30  0.349  150.000000
# 2   LG  144  87  55  2  0.613  1승  38-1-33  49-1-22  0.315  134.500000
# 3   KT  144  80  62  2  0.563  1패  40-1-31  40-1-31  0.308  182.333333
# 4  KIA  144  70  73  1  0.490  1패  31-0-41  39-1-32  0.320  149.000000
# 5   NC  144  67  74  3  0.475  1패  35-3-34  32-0-40  0.336  184.000000
# 6   삼성  144  66  76  2  0.465  2승  33-2-37  33-0-39  0.342  167.333333
# 7   롯데  144  64  76  4  0.457  1승  27-3-42  37-1-34  0.331  177.500000
# 8   두산  144  60  82  2  0.423  2패  29-1-42  31-1-40  0.309  162.666667
# 9   한화  144  46  96  2  0.324  1패  28-0-44  18-2-52  0.289  143.000000

# %%
fig = plt.figure(figsize=(12, 12))
ax = fig.add_subplot(111)
# 산점도
ax.scatter(tusu_pi['승률'],tusu_pi['피안타'])
ax.set_xlabel('승률')
ax.set_ylabel('평균 피안타')
plt.title("승률과 평균 피안타의 산점도")
for i, txt in enumerate(tusu_pi['팀명']):
    plt.text(tusu_pi['승률'][i], tusu_pi['피안타'][i], txt)
plt.show()

# %%
stats.pearsonr(tusu_pi['승률'],tusu_pi['피안타'])
# Out:
# PearsonRResult(statistic=-0.17221821883153499, pvalue=0.634248614402186)

# %%
tusu_sal.groupby(['팀명'])[['삼진']].max().reset_index()
# Out:
#     팀명   삼진
# 0  KIA  161
# 1   KT  156
# 2   LG  153
# 3   NC  194
# 4  SSG  170
# 5   두산  138
# 6   롯데  160
# 7   삼성  159
# 8   키움  224
# 9   한화  129

# %%
tusu_sam_max = pd.merge(team_max,tusu_sal.groupby(['팀명'])[['삼진']].max().reset_index(),left_on = '팀명',right_on='팀명')
tusu_sam_max
# Out:
#     팀명  경기수   승   패  무     승률  연속        홈       원정     타율   삼진
# 0  SSG  144  88  52  4  0.629  4패  49-0-23  39-4-29  0.304  170
# 1   키움  144  80  62  2  0.563  1승  39-1-32  41-1-30  0.349  224
# 2   LG  144  87  55  2  0.613  1승  38-1-33  49-1-22  0.315  153
# 3   KT  144  80  62  2  0.563  1패  40-1-31  40-1-31  0.308  156
# 4  KIA  144  70  73  1  0.490  1패  31-0-41  39-1-32  0.320  161
# 5   NC  144  67  74  3  0.475  1패  35-3-34  32-0-40  0.336  194
# 6   삼성  144  66  76  2  0.465  2승  33-2-37  33-0-39  0.342  159
# 7   롯데  144  64  76  4  0.457  1승  27-3-42  37-1-34  0.331  160
# 8   두산  144  60  82  2  0.423  2패  29-1-42  31-1-40  0.309  138
# 9   한화  144  46  96  2  0.324  1패  28-0-44  18-2-52  0.289  129

# %%
stats.pearsonr(tusu_sam_max['승률'],tusu_sam_max['삼진'])
# Out:
# PearsonRResult(statistic=0.4643466482609879, pvalue=0.17637769858520583)
