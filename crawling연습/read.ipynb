# %%
import pandas as pd
pd.read_csv("df_intermediate_100.csv")
# Out:
#         seq         codeName contentsTitle  \
# 0     40192          설계기준 총칙       1. 일반사항
# 1     40192          설계기준 총칙        1.1 목적
# 2     40192          설계기준 총칙      1.2 적용범위
# 3     40192          설계기준 총칙      1.3 참고기준
# 4     40192          설계기준 총칙   1.3.1 관련 법규
# ...     ...              ...           ...
# 2958  41028  비계 및 안전시설물 설계기준  2.7.9 와이어 로프
# 2959  41028  비계 및 안전시설물 설계기준         3. 설계
# 2960  41028  비계 및 안전시설물 설계기준      3.1 일반사항
# 2961  41028  비계 및 안전시설물 설계기준        3.2 비계
# 2962  41028  비계 및 안전시설물 설계기준     3.3 안전시설물
#
#                                                 subView
# 0                                           <p><br></p>
# 1     <p>(1) 이 기준은 지반, 콘크리트, 강구조, 내진, 가시설, 교량, 터널, 설...
# 2     <p>(1) 이 기준의 적용범위는 지반, 콘크리트, 강구조, 내진, 가시설, 교량,...
# 3                                           <p><br></p>
# 4     <p>(1)<span> </span>건설공사의 설계 및 시공 시 준수하여야 하는 관...
# ...                                                 ...
# ...

# %%
import pandas as pd
pd.read_csv("df_intermediate_200.csv")
# Out:
#         seq          codeName    contentsTitle  \
# 0        82  교량설계 일반사항(일반설계법)          1. 일반사항
# 1        82  교량설계 일반사항(일반설계법)         1.1 적용범위
# 2        82  교량설계 일반사항(일반설계법)         1.2 용어정의
# 3        82  교량설계 일반사항(일반설계법)     1.3 해석과 설계원칙
# 4        82  교량설계 일반사항(일반설계법)     1.3.1 설계의 원칙
# ...     ...               ...              ...
# 3323  30338             수변전설비        4.1 기기 선정
# 3324  30338             수변전설비        4.2 용량 산정
# 3325  30338             수변전설비    4.2.1 부하용량 산정
# 3326  30338             수변전설비  4.2.2 변압기 용량 산정
# 3327  30338             수변전설비     4.3 에너지절약 설계
#
#                                                 subView
# 0                                                   <p>
# 1     <p>(1) 이 기준은 철도건설 및 개량에 따라 철도선로 상에 건설하는 지간 150...
# 2     <p>이 코드에서 쓰이는 용어의 의미는 다음과 같다.</p><p>● 가도교 : 도로...
# 3                                                   NaN
# 4     <p>(1) 철도교량은 안전하고도 경제적이며 목적에 맞는 것이어야 한다. 따라서 실...
# ...                                                 ...
# ...
